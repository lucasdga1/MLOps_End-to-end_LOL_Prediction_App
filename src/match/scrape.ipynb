# %%
# Importação de bibliotecas
import pandas as pd
from pathlib import Path

# %%
# Carrega o dataframe
MATCH_CSV = Path ("D:\PyCharm 2026.1.4\Projeto_LOL\src\match\high_diamond_ranked_10min.csv")

df = pd.read_csv(MATCH_CSV)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\lucas\AppData\Local\Temp\ipykernel_22308\2453577258.py:1: SyntaxWarning: invalid escape sequence '\P'
#   MATCH_CSV = Path ("D:\PyCharm 2026.1.4\Projeto_LOL\src\match\high_diamond_ranked_10min.csv")

# %%
# Verifica o carregamento
df.head()
# Out:
#        gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0  4519157822         0               28                   2               1
# 1  4523371949         0               12                   1               0
# 2  4521474530         0               15                   0               0
# 3  4524384067         0               43                   1               0
# 4  4436033771         0               75                   4               0
#
#    blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  ...  \
# 0          9           6           11                  0            0  ...
# 1          5           5            5                  0            0  ...
# 2          7          11            4                  1            1  ...
# 3          4           5            5                  1            0  ...
# 4          6           6            6                  0            0  ...
#
# ...

# %%
df.shape
# Out:
# (9879, 40)

# %%
"""
Aqui você seleciona qual partida das 9879 prever no app
"""
select = df.iloc[33]
select
# Out:
# gameId                          4.497859e+09
# blueWins                        0.000000e+00
# blueWardsPlaced                 1.500000e+01
# blueWardsDestroyed              2.000000e+00
# blueFirstBlood                  1.000000e+00
# blueKills                       5.000000e+00
# blueDeaths                      4.000000e+00
# blueAssists                     4.000000e+00
# blueEliteMonsters               0.000000e+00
# blueDragons                     0.000000e+00
# blueHeralds                     0.000000e+00
# blueTowersDestroyed             0.000000e+00
# blueTotalGold                   1.563400e+04
# blueAvgLevel                    6.800000e+00
# blueTotalExperience             1.635500e+04
# blueTotalMinionsKilled          2.010000e+02
# blueTotalJungleMinionsKilled    4.500000e+01
# blueGoldDiff                    7.100000e+01
# blueExperienceDiff             -3.590000e+02
# blueCSPerMin                    2.010000e+01
# blueGoldPerMin                  1.563400e+03
# ...

# %%
select.to_csv(r'D:\PyCharm 2026.1.4\Projeto_LOL\src\match\app_test.csv', index=False)
