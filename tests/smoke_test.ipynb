# %%
import sys
from pathlib import Path

# Force notebook to recognize project root
import os
ROOT = Path(os.getcwd()).resolve().parents[0] # one level up from tests/
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

import pandas as pd
from src.inference_pipeline.inference import predict

# Load a few rows of already preprocessed data
sample_path = ROOT / "data/raw/base_lol.csv"
df = pd.read_csv(sample_path).sample(5, random_state=42).reset_index(drop=True)


print("Input sample:")
display(df.head())

# Run inference
preds_df = predict(df)
print("✅ Predictions returned")
display(preds_df[["predicted_winner"]].head())
# Out:
# Input sample:
#        gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0  4516180818         1               20                   1               1
# 1  4517684472         0               13                   1               0
# 2  4468356736         0               14                   2               1
# 3  4507786946         1               16                   2               1
# 4  4515728718         0               11                   0               0
#
#    blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  ...  \
# 0          5           6            6                  1            1  ...
# 1          1           3            1                  0            0  ...
# 2         10          10           17                  1            1  ...
# 3          7           6            7                  2            1  ...
# 4          5           8            1                  0            0  ...
#
#    redTowersDestroyed  redTotalGold  redAvgLevel  redTotalExperience  \
# 0                   0         16643          6.8               17556
# 1                   0         17065          7.2               19934
# 2                   0         17860          7.2               18838
# 3                   0         15975          7.0               17368
# 4                   0         18339          7.4               20334
#
#    redTotalMinionsKilled  redTotalJungleMinionsKilled  redGoldDiff  \
# 0                    210                           48          608
# 1                    250                           76         2373
# 2                    206                           56         -987
# 3                    199                           62        -1478
# 4                    229                           59         3750
#
#    redExperienceDiff  redCSPerMin  redGoldPerMin
# 0                703         21.0         1664.3
# 1               1592         25.0         1706.5
# 2               -642         20.6         1786.0
# 3               -483         19.9         1597.5
# 4               4961         22.9         1833.9
#
# [5 rows x 40 columns]
# ✅ Data processing completed (saved to \opt\airflow\dags\data\cleaned).
# Processed Data: (5, 39)
# ✅ Predictions returned
#    predicted_winner
# 0                 0
# 1                 0
# 2                 1
# 3                 1
# 4                 0
