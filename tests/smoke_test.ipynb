# %%
import sys
from pathlib import Path

# Force notebook to recognize project root
import os
ROOT = Path(os.getcwd()).resolve().parents[0] # one level up from tests/
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

import pandas as pd
from src.inference_pipeline.inference import predict

# Load a few rows of already preprocessed data
sample_path = ROOT / "data/raw/Base_LOL.csv"
df = pd.read_csv(sample_path).sample(5, random_state=42).reset_index(drop=True)


print("Input sample:")
display(df.head())

# Run inference
preds_df = predict(df)
print("✅ Predictions returned")
display(preds_df[["predicted_winner"]].head())
# Out:
# Input sample:
#        gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0  4519205334         0               14                   2               0
# 1  4501108199         1               15                   1               1
# 2  4526718235         1               10                   5               0
# 3  4524404839         1               81                   5               0
# 4  4510888904         0               18                   2               0
#
#    blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  ...  \
# 0          4           8            3                  2            1  ...
# 1         10           5           10                  0            0  ...
# 2         16          13           16                  2            1  ...
# 3         11          11           14                  0            0  ...
# 4          8          13            5                  0            0  ...
#
#    redTowersDestroyed  redTotalGold  redAvgLevel  redTotalExperience  \
# 0                   1         19675          7.4               19936
# 1                   0         15577          6.8               17645
# 2                   0         18891          7.0               17820
# 3                   0         17472          7.0               17509
# 4                   0         19133          7.2               19174
#
#    redTotalMinionsKilled  redTotalJungleMinionsKilled  redGoldDiff  \
# 0                    232                           67         4790
# 1                    203                           44        -2301
# 2                    191                           52         -546
# 3                    200                           24        -1441
# 4                    223                           38         3056
#
#    redExperienceDiff  redCSPerMin  redGoldPerMin
# 0               2126         23.2         1967.5
# 1               -603         20.3         1557.7
# 2               -680         19.1         1889.1
# 3               -922         20.0         1747.2
# 4               2462         22.3         1913.3
#
# [5 rows x 40 columns]
# ✅ Data processing completed (saved to src\data\cleaned).
# Processed Data: (5, 39)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 22
#      18 print("Input sample:")
#      19 display(df.head())
#      20
#      21 # Run inference
# ---> 22 preds_df = predict(df)
#      23 print("✅ Predictions returned")
#      24 display(preds_df[["predicted_winner"]].head())
#
# File D:\PyCharm 2026.1.4\Projeto_LOL\src\inference_pipeline\inference.py:61, in predict(input_df, model_path)
#      59 # Load model and predict
#      60 model = load(model_path)
# ---> 61 preds = model.predict(df)
#      63 # Build output
#      64 out = df.copy()
#
# File D:\PyCharm 2026.1.4\Projeto_LOL\.venv\Lib\site-packages\xgboost\core.py:553, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     551 for k, arg in zip(sig.parameters, args):
#     552     kwargs[k] = arg
# --> 553 return func(**kwargs)
#
# File D:\PyCharm 2026.1.4\Projeto_LOL\.venv\Lib\site-packages\xgboost\sklearn.py:1843, in XGBClassifier.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1832 @_deprecate_positional_args
#    1833 def predict(
#    1834     self,
#    (...)   1840     iteration_range: Optional[IterationRange] = None,
#    1841 ) -> ArrayLike:
#    1842     with config_context(verbosity=self.verbosity):
# -> 1843         class_probs = super().predict(
#    1844             X=X,
#    1845             output_margin=output_margin,
#    1846             validate_features=validate_features,
#    1847             base_margin=base_margin,
#    1848             iteration_range=iteration_range,
#    1849         )
#    1850         if output_margin:
#    1851             # If output_margin is active, simply return the scores
#    1852             return class_probs
#
# File D:\PyCharm 2026.1.4\Projeto_LOL\.venv\Lib\site-packages\xgboost\core.py:553, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     551 for k, arg in zip(sig.parameters, args):
#     552     kwargs[k] = arg
# --> 553 return func(**kwargs)
#
# File D:\PyCharm 2026.1.4\Projeto_LOL\.venv\Lib\site-packages\xgboost\sklearn.py:1447, in XGBModel.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1445 if self._can_use_inplace_predict():
#    1446     try:
# -> 1447         predts = self.get_booster().inplace_predict(
#    1448             data=X,
#    1449             iteration_range=iteration_range,
#    1450             predict_type="margin" if output_margin else "value",
#    1451             missing=self.missing,
#    1452             base_margin=base_margin,
#    1453             validate_features=validate_features,
#    1454         )
#    1455         if _is_cupy_alike(predts):
#    1456             cp = import_cupy()
#
# File D:\PyCharm 2026.1.4\Projeto_LOL\.venv\Lib\site-packages\xgboost\core.py:553, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     551 for k, arg in zip(sig.parameters, args):
#     552     kwargs[k] = arg
# --> 553 return func(**kwargs)
#
# File D:\PyCharm 2026.1.4\Projeto_LOL\.venv\Lib\site-packages\xgboost\core.py:2666, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2664     data, fns, _ = _transform_pandas_df(data, enable_categorical)
#    2665     if validate_features:
# -> 2666         self._validate_features(fns)
#    2667 if _is_list(data) or _is_tuple(data):
#    2668     data = np.array(data)
#
# File D:\PyCharm 2026.1.4\Projeto_LOL\.venv\Lib\site-packages\xgboost\core.py:3264, in Booster._validate_features(self, feature_names)
#    3258 if my_missing:
#    3259     msg += (
#    3260         "\ntraining data did not have the following fields: "
#    3261         + ", ".join(str(s) for s in my_missing)
#    3262     )
# -> 3264 raise ValueError(msg.format(self.feature_names, feature_names))
#
# ValueError: feature_names mismatch: ['blueWardsPlaced', 'blueWardsDestroyed', 'blueFirstBlood', 'blueKills', 'blueDeaths', 'blueAssists', 'blueEliteMonsters', 'blueDragons', 'blueHeralds', 'blueTowersDestroyed', 'blueTotalGold', 'blueAvgLevel', 'blueTotalExperience', 'blueTotalMinionsKilled', 'blueTotalJungleMinionsKilled', 'blueGoldDiff', 'blueExperienceDiff', 'blueCSPerMin', 'blueGoldPerMin', 'redWardsPlaced', 'redWardsDestroyed', 'redFirstBlood', 'redKills', 'redDeaths', 'redAssists', 'redEliteMonsters', 'redDragons', 'redHeralds', 'redTowersDestroyed', 'redTotalGold', 'redAvgLevel', 'redTotalExperience', 'redTotalMinionsKilled', 'redTotalJungleMinionsKilled', 'redGoldDiff', 'redExperienceDiff', 'redCSPerMin', 'redGoldPerMin'] ['gameId', 'blueWardsPlaced', 'blueWardsDestroyed', 'blueFirstBlood', 'blueKills', 'blueDeaths', 'blueAssists', 'blueEliteMonsters', 'blueDragons', 'blueHeralds', 'blueTowersDestroyed', 'blueTotalGold', 'blueAvgLevel', 'blueTotalExperience', 'blueTotalMinionsKilled', 'blueTotalJungleMinionsKilled', 'blueGoldDiff', 'blueExperienceDiff', 'blueCSPerMin', 'blueGoldPerMin', 'redWardsPlaced', 'redWardsDestroyed', 'redFirstBlood', 'redKills', 'redDeaths', 'redAssists', 'redEliteMonsters', 'redDragons', 'redHeralds', 'redTowersDestroyed', 'redTotalGold', 'redAvgLevel', 'redTotalExperience', 'redTotalMinionsKilled', 'redTotalJungleMinionsKilled', 'redGoldDiff', 'redExperienceDiff', 'redCSPerMin', 'redGoldPerMin']
# training data did not have the following fields: gameId
